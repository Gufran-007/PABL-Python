# %% [markdown]
# <a href="https://colab.research.google.com/github/Gufran-007/PABL-Python/blob/main/Experiment_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("lakshmi25npathi/bike-sharing-dataset")

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(f"{path}/day.csv")
# print(df.shape)

relevant_var = df[["temp", "hum", "windspeed", "cnt"]]
# print(relevant_var.head())

# plt.scatter(df["temp"], df["cnt"])
# plt.xlabel("Temperature")
# plt.ylabel("Count")
# plt.title("Temperature vs Bike Rental Count")
# plt.show()

# plt.scatter(df["hum"], df["cnt"])
# plt.xlabel("Humidity")
# plt.ylabel("Count")
# plt.title("Humidity vs Bike Rental Count")
# plt.show()

# plt.scatter(df["windspeed"], df["cnt"])
# plt.xlabel("Windspeed")
# plt.ylabel("Count")
# plt.title("Windspeed vs Bike Rental Count")
# plt.show()

# corr = df[["temp", "hum", "windspeed", "cnt"]].corr()
# print(corr["cnt"])
# print(corr)

# corr = df[["temp", "hum", "windspeed", "cnt"]].corr()
# sns.heatmap(corr, annot=True, cmap="coolwarm", fmt="0.2f")
# plt.title("Correlation Heatmap")
# plt.show()

# temp and rental count have a positive relationship
# humidity and rental count show a weak negative relationship.
# windspeed and rental count also show a weak negative relationship.

# sns.regplot(x="temp", y="cnt", data=df)
# plt.title("Temperature vs Bike Rental Count")
# plt.show()

# sns.scatterplot(data=df, x="temp", y="cnt", hue="season")
# plt.title("Temperature vs Bike Rental Count Across Seasons")
# plt.show()

# correlation doesn't imply increase rentals/ causation.
# temp vs rental count = corr(approx 0.63)
# humidity
