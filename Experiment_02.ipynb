# %% [markdown]
# <a href="https://colab.research.google.com/github/Gufran-007/PABL-Python/blob/main/Experiment_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("vivek468/superstore-dataset-final")

import pandas as pd
import matplotlib.pyplot as plt
import os

full_path = os.path.join(path, "Sample - Superstore.csv")
df = pd.read_csv(full_path, encoding='latin1')

# category_sales = df.groupby('Category')['Sales'].sum()
# print(category_sales)
# category_sales.plot(kind='bar')
# plt.xlabel('Category')
# plt.ylabel('Total Sales')
# plt.title('Total Sales by Category')
# plt.show()

# category_sales.plot(kind='bar')
# plt.ylim(700000, 850000)
# plt.title('Sales Category-wise Mislead')
# plt.ylabel('Sales')
# plt.show()

# category_sales.plot(kind='bar')
# plt.ylim(0, 900000)
# plt.title('Sales by Product Category')
# plt.xlabel('Category')
# plt.ylabel('Total Sales')
# plt.xticks(rotation=0)
# plt.show()
