# %% [markdown]
# <a href="https://colab.research.google.com/github/Gufran-007/PABL-Python/blob/main/Experiment_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("lainguyn123/student-performance-factors")

import pandas as pd
df = pd.read_csv(f"{path}/StudentPerformanceFactors.csv")
# print(df.shape)
# print(df.head(5))
# print(df.tail(5))
# print("Rows: ", df.shape[0])
# print("Columns: ", df.shape[1])
# print(df.columns.tolist()) - type1
# columns = df.columns.tolist() - type2
# for i in range(0, len(columns), 5):
#     print(columns[i:i+5])
# print("Numerical Variables:")
# print(df.select_dtypes(include=['number']).columns.tolist())
# print("Categorical Variables:")
# print(df.select_dtypes(exclude=['number']).columns.tolist())
# data_dictionary = {"Hours_Studied": "Study hours", "Attendance": "Attendance percentage", "Previous_Scores": "Previous exam scores"}
# print(data_dictionary)
