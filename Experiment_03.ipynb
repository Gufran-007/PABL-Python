# %% [markdown]
# <a href="https://colab.research.google.com/github/Gufran-007/PABL-Python/blob/main/Experiment_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("uciml/adult-census-income")

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv(f"{path}/adult.csv")
col_calc = df["age"]

#1.
# print("Mean: ",col_calc.mean())
# print("Median: ",col_calc.median())
# print("Mode: ",col_calc.mode())

#2.
# print("Minimum: ",col_calc.min())
# print("Maximum: ",col_calc.max())
# range_val = col_calc.max() - col_calc.min()
# print("Range: ",range_val)

#3.
# income_var = col_calc.var()
# print(f"Variance: {income_var}")
# income_std = col_calc.std()
# print(f"Standard Deviation: {income_std}")

#4.
# q1, q2, q3 = col_calc.quantile([0.25, 0.50, 0.75])
# print(f"q1 = {q1}, q2 = {q2}, q3 = {q3}")

#5. Outlier
# iqr = q3-q1
# lower = q1-1.5*iqr
# upper = q3+1.5*iqr
# outliers = col_calc[(col_calc < lower) | (col_calc > upper)]
# print(len(outliers))
# print("Lower limit: ", lower)
# print("Upper limit: ", upper)
# print("Number of outliers: ", len(outliers))


# print(df.info())
# print(df.isnull().sum())
# print(df.duplicated().sum())
# print(df.drop_duplicates())
# print(df.T.duplicated().sum())
# print(df.duplicated(subset=["fnlwgt", "age"]))


# plt.hist(col_calc, bins=20, edgecolor="black")
# plt.xlabel("Age")
# plt.ylabel("Frequency")
# plt.title("Histogram of Age")
# plt.show()

# sns.kdeplot(col_calc, fill=True)
# plt.xlabel("Age")
# plt.ylabel("Density")
# plt.title("Kernel Density Estimation of Age")
# plt.show()

# sns.boxplot(x=col_calc)
# plt.xlabel("Age")
# plt.ylabel("Value")
# plt.title("Box Plot of Age")
# plt.show()

print("Skewness: ", col_calc.skew())
# Out:
# Using Colab cache for faster access to the 'adult-census-income' dataset.
# Skewness:  0.5587433694130483
